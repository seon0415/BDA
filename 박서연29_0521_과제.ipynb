# %% [markdown]
# <a href="https://colab.research.google.com/github/seon0415/BDA/blob/main/%EB%B0%95%EC%84%9C%EC%97%B029_0521_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import datetime

# %% [markdown]
# ##datetime 이용하기

# %%
#날짜
date=datetime.date(year=2023, month=4, day=20)
date
# Out:
# datetime.date(2023, 4, 20)

# %%
#시간
time=datetime.time(hour=10, minute=20, second=10)
time
# Out:
# datetime.time(10, 20, 10)

# %%
#timedelta
td = datetime.timedelta(days=20, hours=10)
td
# Out:
# datetime.timedelta(days=20, seconds=36000)

# %%
print(date+td)
# Out:
# 2023-05-10

# %%
#pandas
pd.to_datetime('2023-05-21')
# Out:
# Timestamp('2023-05-21 00:00:00')

# %%
a=pd.Series(['2023-05-10', '2023/5/11', '2023.05.12'])
pd.to_datetime(a)
# Out:
# 0   2023-05-10
# 1   2023-05-11
# 2   2023-05-12
# dtype: datetime64[ns]

# %%
b=pd.Series(['2023-05-10', '2023/4/31'])
pd.to_datetime(b, errors='coerce')
#정상적이지 않은 값은 na로 변환
# Out:
# 0   2023-05-10
# 1          NaT
# dtype: datetime64[ns]

# %% [markdown]
# ##CRIME 데이터

# %% [markdown]
# ###1. datetime형식인지 확인하기

# %%
crime= pd.read_csv('crime.csv')

# %%
crime.head(10)
# Out:
#    Unnamed: 0                 OFFENSE_TYPE_ID           OFFENSE_CATEGORY_ID  \
# 0           0       traffic-accident-dui-duid              traffic-accident
# 1           1      vehicular-eluding-no-chase              all-other-crimes
# 2           2            disturbing-the-peace               public-disorder
# 3           3                          curfew               public-disorder
# 4           4              aggravated-assault            aggravated-assault
# 5           5  violation-of-restraining-order              all-other-crimes
# 6           6       traffic-accident-dui-duid              traffic-accident
# 7           7                      assault-dv  other-crimes-against-persons
# 8           8       criminal-mischief-mtr-veh               public-disorder
# 9           9            criminal-trespassing              all-other-crimes
#
#         REPORTED_DATE     GEO_LON    GEO_LAT            NEIGHBORHOOD_ID  \
# ...

# %%
#날짜컬럼을 날짜형식으로 바꾸기(데이터 값이 datetime로 꼭 변경이 되어야만 시계열 데이터로 사용할 수 있어서)
crime['REPORTED_DATE']=pd.to_datetime(crime['REPORTED_DATE'])
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 460911 entries, 0 to 460910
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Unnamed: 0           460911 non-null  int64
#  1   OFFENSE_TYPE_ID      460911 non-null  object
#  2   OFFENSE_CATEGORY_ID  460911 non-null  object
#  3   REPORTED_DATE        460911 non-null  datetime64[ns]
#  4   GEO_LON              457296 non-null  float64
#  5   GEO_LAT              457296 non-null  float64
#  6   NEIGHBORHOOD_ID      460911 non-null  object
#  7   IS_CRIME             460911 non-null  int64
#  8   IS_TRAFFIC           460911 non-null  int64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(3)
# memory usage: 31.6+ MB

# %%
#날짜컬럼을 인덱스로 설정하기
crime_df=crime.set_index('REPORTED_DATE')
crime_df
# Out:
#                      Unnamed: 0               OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2014-06-29 02:01:00           0     traffic-accident-dui-duid
# 2014-06-29 01:54:00           1    vehicular-eluding-no-chase
# 2014-06-29 02:00:00           2          disturbing-the-peace
# 2014-06-29 02:18:00           3                        curfew
# 2014-06-29 04:17:00           4            aggravated-assault
# ...                         ...                           ...
# 2017-09-13 05:48:00      460906    burglary-business-by-force
# 2017-09-12 20:37:00      460907  weapon-unlawful-discharge-of
# 2017-09-12 16:32:00      460908        traf-habitual-offender
# 2017-09-12 13:04:00      460909       criminal-mischief-other
# 2017-09-12 09:30:00      460910                   theft-other
#
#                     OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT  \
# REPORTED_DATE
# 2014-06-29 02:01:00    traffic-accident -105.000149  39.745753
# ...

# %% [markdown]
# ###2. loc이용해서 추출하기

# %% [markdown]
# ####날짜

# %%
#연도기준
crime_df.loc['2014'].sort_index()
# Out:
#                      Unnamed: 0            OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2014-01-01 00:08:00      214696     traf-habitual-offender
# 2014-01-01 00:08:00       99814                 traf-other
# 2014-01-01 00:38:00      224109     theft-of-motor-vehicle
# 2014-01-01 00:39:00       83972             robbery-street
# 2014-01-01 01:00:00      236308         aggravated-assault
# ...                         ...                        ...
# 2014-12-31 23:59:00      126879     theft-of-motor-vehicle
# 2014-12-31 23:59:00      226091  weapon-carrying-concealed
# 2014-12-31 23:59:00       97411                 assault-dv
# 2014-12-31 23:59:00      148309           traffic-accident
# 2014-12-31 23:59:00      226092       disturbing-the-peace
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT  \
# REPORTED_DATE
# 2014-01-01 00:08:00              all-other-crimes -104.841945  39.773764
# 2014-01-01 00:08:00              all-other-crimes -104.841945  39.773764
# ...

# %%
#월기준
crime_df.loc['2014-09'].sort_index()
# Out:
#                      Unnamed: 0               OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2014-09-01 00:03:00      208966          disturbing-the-peace
# 2014-09-01 00:07:00      207496           drug-pcs-other-drug
# 2014-09-01 00:11:00      220517                    traf-other
# 2014-09-01 00:26:00      220522              traffic-accident
# 2014-09-01 00:36:00      165723          criminal-trespassing
# ...                         ...                           ...
# 2014-09-30 23:07:00      211579     public-order-crimes-other
# 2014-09-30 23:09:00      211577      police-false-information
# 2014-09-30 23:09:00      100248                theft-shoplift
# 2014-09-30 23:40:00      209477                    traf-other
# 2014-09-30 23:56:00      130569  traffic-accident-hit-and-run
#
#                     OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT  \
# REPORTED_DATE
# 2014-09-01 00:03:00     public-disorder -104.958341  39.675299
# ...

# %%
#일기준
crime_df.loc['2014-09-13'].count()
# Out:
# Unnamed: 0             204
# OFFENSE_TYPE_ID        204
# OFFENSE_CATEGORY_ID    204
# GEO_LON                202
# GEO_LAT                202
# NEIGHBORHOOD_ID        204
# IS_CRIME               204
# IS_TRAFFIC             204
# dtype: int64

# %% [markdown]
# ####시간
# - between_time
# - at_time

# %%
crime_dt=crime_df.loc['2014'].sort_index()

# %%
crime_dt.between_time('13:00', '15:00')['Unnamed: 0'].count()
# Out:
# 9628

# %%
#시간 사이
crime_dt.between_time('13:00', '15:00')
# Out:
#                      Unnamed: 0               OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2014-01-01 13:08:00        1251              traffic-accident
# 2014-01-01 13:54:00      146990   burglary-residence-no-force
# 2014-01-01 13:55:00      200314    burglary-business-by-force
# 2014-01-01 14:22:00      133765             liquor-possession
# 2014-01-01 14:28:00      137563                    assault-dv
# ...                         ...                           ...
# 2014-12-31 14:48:00      138208   burglary-residence-by-force
# 2014-12-31 14:50:00      222501              traffic-accident
# 2014-12-31 14:58:00      303463  traffic-accident-hit-and-run
# 2014-12-31 15:00:00      205211   harassment-sexual-in-nature
# 2014-12-31 15:00:00      217583        menacing-felony-w-weap
#
#                               OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT  \
# REPORTED_DATE
# 2014-01-01 13:08:00              traffic-accident -104.912616  39.651368
# ...

# %%
#시간 정각
crime_dt.at_time('17:50')
# Out:
#                      Unnamed: 0               OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2014-01-06 17:50:00      114954                theft-shoplift
# 2014-01-06 17:50:00      231834              traffic-accident
# 2014-01-07 17:50:00        2255   burglary-residence-no-force
# 2014-01-26 17:50:00       84974                    traf-other
# 2014-01-27 17:50:00      133303  traffic-accident-hit-and-run
# ...                         ...                           ...
# 2014-12-12 17:50:00      215438   burglary-residence-by-force
# 2014-12-13 17:50:00      156529  traffic-accident-hit-and-run
# 2014-12-18 17:50:00      232266     public-order-crimes-other
# 2014-12-27 17:50:00      188685              traffic-accident
# 2014-12-27 17:50:00      190738                   theft-other
#
#                     OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT  \
# REPORTED_DATE
# 2014-01-06 17:50:00             larceny -104.992734  39.745315
# ...

# %%
#처음부터 5일동안
crime_dt.first('5D')
# Out:
#                      Unnamed: 0            OFFENSE_TYPE_ID  \
# REPORTED_DATE
# 2014-01-01 00:08:00      214696     traf-habitual-offender
# 2014-01-01 00:08:00       99814                 traf-other
# 2014-01-01 00:38:00      224109     theft-of-motor-vehicle
# 2014-01-01 00:39:00       83972             robbery-street
# 2014-01-01 01:00:00      236308         aggravated-assault
# ...                         ...                        ...
# 2014-01-05 23:21:00      248473           traffic-accident
# 2014-01-05 23:28:00      235140  weapon-carrying-concealed
# 2014-01-05 23:28:00      235141       drug-cocaine-possess
# 2014-01-05 23:36:00      234679    criminal-mischief-other
# 2014-01-06 00:06:00      239688     menacing-felony-w-weap
#
#                     OFFENSE_CATEGORY_ID     GEO_LON    GEO_LAT  \
# REPORTED_DATE
# 2014-01-01 00:08:00    all-other-crimes -104.841945  39.773764
# 2014-01-01 00:08:00    all-other-crimes -104.841945  39.773764
# ...

# %% [markdown]
# ###3. resample(월별, 일별, 주별 값을 계산)

# %%
crime_sp=crime_dt[['IS_CRIME']]
crime_sp
# Out:
#                      IS_CRIME
# REPORTED_DATE
# 2014-01-01 00:08:00         1
# 2014-01-01 00:08:00         1
# 2014-01-01 00:38:00         1
# 2014-01-01 00:39:00         1
# 2014-01-01 01:00:00         1
# ...                       ...
# 2014-12-31 23:59:00         1
# 2014-12-31 23:59:00         0
# 2014-12-31 23:59:00         1
# 2014-12-31 23:59:00         1
# 2014-12-31 23:59:00         1
#
# [84421 rows x 1 columns]

# %%
crime_sp.loc['2014-01-01':'2014-01-05'].count()
# Out:
# IS_CRIME    884
# dtype: int64

# %%
crime_sp.loc['2014-01-01':'2014-01-05'].value_counts()
# Out:
# IS_CRIME
# 1.0         616
# 0.0         268
# dtype: int64

# %%
crime_sp2=crime_dt[['IS_CRIME','IS_TRAFFIC']]

# %% [markdown]
# ####주별로 계산

# %%
crime_sp.resample('W').sum()
# Out:
#                IS_CRIME
# REPORTED_DATE
# 2014-01-05        616.0
# 2014-01-12       1014.0
# 2014-01-19       1096.0
# 2014-01-26       1079.0
# 2014-02-02        911.0
# 2014-02-09        945.0
# 2014-02-16       1256.0
# 2014-02-23       1312.0
# 2014-03-02       1150.0
# 2014-03-09       1157.0
# 2014-03-16       1217.0
# 2014-03-23       1229.0
# 2014-03-30       1255.0
# 2014-04-06       1108.0
# 2014-04-13       1237.0
# 2014-04-20       1141.0
# 2014-04-27       1188.0
# 2014-05-04       1354.0
# 2014-05-11       1160.0
# 2014-05-18       1153.0
# 2014-05-25       1206.0
# 2014-06-01       1241.0
# 2014-06-08       1208.0
# 2014-06-15       1283.0
# 2014-06-22       1201.0
# 2014-06-29       1302.0
# 2014-07-06       1286.0
# 2014-07-13       1204.0
# 2014-07-20       1368.0
# 2014-07-27       1332.0
# 2014-08-03       1356.0
# 2014-08-10       1293.0
# 2014-08-17       1413.0
# 2014-08-24       1301.0
# 2014-08-31       1318.0
# 2014-09-07       1312.0
# ...

# %%
crime_sp2.resample('W').sum()
#'IS_CRIME'이랑'IS_TRAFFIC'은 서로 반대임
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2014-01-05        616.0       268.0
# 2014-01-12       1014.0       397.0
# 2014-01-19       1096.0       327.0
# 2014-01-26       1079.0       349.0
# 2014-02-02        911.0       439.0
# 2014-02-09        945.0       481.0
# 2014-02-16       1256.0       394.0
# 2014-02-23       1312.0       358.0
# 2014-03-02       1150.0       404.0
# 2014-03-09       1157.0       393.0
# 2014-03-16       1217.0       405.0
# 2014-03-23       1229.0       389.0
# 2014-03-30       1255.0       363.0
# 2014-04-06       1108.0       366.0
# 2014-04-13       1237.0       407.0
# 2014-04-20       1141.0       425.0
# 2014-04-27       1188.0       358.0
# 2014-05-04       1354.0       379.0
# 2014-05-11       1160.0       407.0
# 2014-05-18       1153.0       368.0
# 2014-05-25       1206.0       432.0
# 2014-06-01       1241.0       388.0
# 2014-06-08       1208.0       441.0
# 2014-06-15       1283.0       414.0
# ...

# %% [markdown]
# ####월별로 계산

# %%
crime_sp2.resample('M').sum()
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2014-01-31       4530.0      1678.0
# 2014-02-28       4571.0      1646.0
# 2014-03-31       5338.0      1695.0
# 2014-04-30       5032.0      1671.0
# 2014-05-31       5394.0      1765.0
# 2014-06-30       5383.0      1789.0
# 2014-07-31       5729.0      1862.0
# 2014-08-31       5913.0      1899.0
# 2014-09-30       5686.0      1973.0
# 2014-10-31       5628.0      2057.0
# 2014-11-30       4621.0      1783.0
# 2014-12-31       4771.0      1943.0

# %% [markdown]
# ####연별로 계산

# %%
crime_sp2.resample('Y').sum()
# Out:
#                IS_CRIME  IS_TRAFFIC
# REPORTED_DATE
# 2014-12-31      62596.0     21761.0

# %% [markdown]
# ###4. 시계열 그래프

# %%
crime_mon=crime_dt['IS_CRIME'].resample('M').sum()
crime_mon.plot()
# Out:
# <Axes: xlabel='REPORTED_DATE'>

# %%
crime_mon=crime_dt['IS_CRIME'].resample('W').sum()
crime_mon.plot()
# Out:
# <Axes: xlabel='REPORTED_DATE'>

# %% [markdown]
# ##  필수과제1
# - 시계열데이터 문법, 리서치 하셔서 정리하시고 최소 5개 이상 문법 찾아서 코드와 주석처리 해주시면 됩니다.
# - offsets, first 근로기준의 날 뽑을 수도 있고, 첫주의 월요일만 뽑을 수 있음

# %%
import pandas as pd
import datetime

# %%
#2016년 첫주의 월요일, 금요일 날짜 구하기
for month in range(1, 13):
    # 해당 월의 첫 날짜와 마지막 날짜 구하기
    start_date = pd.to_datetime(f'2016-{month}-01')
    end_date = start_date + pd.offsets.MonthEnd()

    # 첫 주 월요일, 금요일 구하기
    first_monday = start_date + pd.offsets.WeekOfMonth(week=0, weekday=0)
    first_friday = pd.date_range(start_date, end_date, freq='W-FRI').min()

    # 첫 주 월요일, 금요일의 날짜 출력
    print(f"2016-",month)      
    print(f"{start_date.strftime('%Y-%m')} first monday: {first_monday.day}")
    print(f"{start_date.strftime('%Y-%m')} first friday: {first_friday.day}")
# Out:
# 2016- 1
# 2016-01 first monday: 4
# 2016-01 first friday: 1
# 2016- 2
# 2016-02 first monday: 7
# 2016-02 first friday: 5
# 2016- 3
# 2016-03 first monday: 7
# 2016-03 first friday: 4
# 2016- 4
# 2016-04 first monday: 4
# 2016-04 first friday: 1
# 2016- 5
# 2016-05 first monday: 2
# 2016-05 first friday: 6
# 2016- 6
# 2016-06 first monday: 6
# 2016-06 first friday: 3
# 2016- 7
# 2016-07 first monday: 4
# 2016-07 first friday: 1
# 2016- 8
# 2016-08 first monday: 5
# 2016-08 first friday: 5
# 2016- 9
# 2016-09 first monday: 5
# 2016-09 first friday: 2
# 2016- 10
# 2016-10 first monday: 3
# 2016-10 first friday: 7
# 2016- 11
# 2016-11 first monday: 7
# 2016-11 first friday: 4
# 2016- 12
# 2016-12 first monday: 5
# 2016-12 first friday: 2

# %% [markdown]
# ## 필수과제2
# - crime 데이터를 가지고 시계열 데이터 분석을 진행해 주세요.
# - 제공된 컬럼을 가지고 범죄건과 비교해서 시계열 데이터 분석을 진행해 주세요!
# - ex) OFFENSE_TYPE_ID 해당 컬럼과 범죄건수와 시계열적인 패턴까지 다 엮어서 어떤식으로 되는지 비교분석이 가능하다.

# %%
import pandas as pd
import datetime

# %%
crime=pd.read_csv('crime.csv')

# %%
crime_1=crime[['OFFENSE_TYPE_ID','IS_CRIME','REPORTED_DATE']]
pd.to_datetime(crime_1['REPORTED_DATE'])

crime_1=crime_1.set_index('REPORTED_DATE')

# %%
crime_1.loc['2014-03'].sort_index()
# Out:
#                                OFFENSE_TYPE_ID  IS_CRIME
# REPORTED_DATE
# 2014-03-01 00:02:00                 traf-other         1
# 2014-03-01 00:19:00                 traf-other         1
# 2014-03-01 00:22:00                 traf-other         1
# 2014-03-01 00:33:00                 traf-other         1
# 2014-03-01 01:03:00                 traf-other         1
# ...                                        ...       ...
# 2014-03-31 23:02:00                theft-other         1
# 2014-03-31 23:14:00             robbery-street         1
# 2014-03-31 23:24:00                 traf-other         1
# 2014-03-31 23:24:00    drug-poss-paraphernalia         1
# 2014-03-31 23:58:00  traffic-accident-dui-duid         0
#
# [7043 rows x 2 columns]

# %%
crime_1.loc['2014-05'].between_time('7:00','12:00')['IS_CRIME'].value_counts()
# Out:
# 1    1052
# 0     391
# Name: IS_CRIME, dtype: int64

# %%
crime_sp1=crime_1.loc['2014-05'].between_time('7:00','12:00').sort_index()

# %%
crime_sp1['IS_CRIME'].resample('D').sum()
# Out:
# REPORTED_DATE
# 2014-05-01    50
# 2014-05-02    40
# 2014-05-03    22
# 2014-05-04    17
# 2014-05-05    49
# 2014-05-06    33
# 2014-05-07    35
# 2014-05-08    21
# 2014-05-09    41
# 2014-05-10    38
# 2014-05-11    25
# 2014-05-12    29
# 2014-05-13    28
# 2014-05-14    30
# 2014-05-15    35
# 2014-05-16    42
# 2014-05-17    15
# 2014-05-18    20
# 2014-05-19    56
# 2014-05-20    37
# 2014-05-21    42
# 2014-05-22    41
# 2014-05-23    33
# 2014-05-24    29
# 2014-05-25    26
# 2014-05-26    33
# 2014-05-27    49
# 2014-05-28    42
# 2014-05-29    32
# 2014-05-30    33
# 2014-05-31    29
# Freq: D, Name: IS_CRIME, dtype: int64

# %%
crime_sp1[['IS_CRIME']].resample('D').sum().plot()
# Out:
# <Axes: xlabel='REPORTED_DATE'>

# %%
crime_sp1['OFFENSE_TYPE_ID'].value_counts().idxmax()
# Out:
# 'traffic-accident'

# %%
crime_sp1[crime_sp1['OFFENSE_TYPE_ID'] == 'traffic-accident'][['OFFENSE_TYPE_ID']].resample('D').count().plot()
# Out:
# <Axes: xlabel='REPORTED_DATE'>
